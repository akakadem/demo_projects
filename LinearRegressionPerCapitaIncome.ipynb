# %% [markdown]
# <a href="https://colab.research.google.com/github/akakadem/demo_projects/blob/main/LinearRegressionPerCapitaIncome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/canada_per_capita_income.csv')

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.rename(columns={'per capita income (US$)': 'income'}, inplace=True)
display(df.head())
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
plt.scatter(df['year'], df['income'], color='red', marker= '+')
plt.xlabel('Year')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
from sklearn.linear_model import LinearRegression

# %%
line = LinearRegression()
line.fit(df[['year']], df['income'])
# Out:
# LinearRegression()

# %%
line.coef_
# Out:
# array([828.46507522])

# %%
line.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
line.predict([[2025]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45431.01947053])

# %%
828.46507522*2025 + -1632210.7578554575
# Out:
# 45431.01946504251

# %%
plt.scatter(df['year'], df['income'], color='red', marker= '+')
plt.plot(df['year'], line.predict(df[['year']]), color='blue')
plt.xlabel('Year')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
dfus = pd.read_csv('/content/us_per_capita_income.csv')

# %%
dfus
# Out:
#     year        income
# 0   1970   4553.443166
# 1   1971   4862.801957
# 2   1972   5308.059146
# 3   1973   5879.222097
# 4   1974   6121.835494
# 5   1975   6530.889097
# 6   1976   7209.041869
# 7   1977   7948.156401
# 8   1978   8893.574278
# 9   1979   9517.841073
# 10  1980  10117.118070
# 11  1981  11452.057500
# 12  1982  12043.706900
# 13  1983  12770.516490
# 14  1984  14283.904770
# 15  1985  15165.045480
# 16  1986  15855.901010
# 17  1987  16750.110970
# 18  1988  18162.287250
# 19  1989  19138.556890
# 20  1990  19905.262840
# 21  1991  20284.239920
# 22  1992  21195.537030
# 23  1993  21893.222600
# 24  1994  23103.561400
# 25  1995  24106.773230
# 26  1996  25325.974710
# 27  1997  26804.187220
# 28  1998  28277.595090
# 29  1999  29584.421580
# 30  2000  31166.938140
# 31  2001  31888.818030
# 32  2002  32505.703800
# 33  2003  33555.338960
# 34  2004  35535.186900
# 35  2005  37454.472250
# 36  2006  39721.626650
# 37  2007  40525.819750
# 38  2008  40165.550980
# ...

# %%
plt.scatter(dfus['year'], dfus['income'], color='blue', marker= '+')
plt.xlabel('Year')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
from sklearn.linear_model import LinearRegression
lineus = LinearRegression()
lineus.fit(dfus[['year']], dfus['income'])
# Out:
# LinearRegression()

# %%
lineus.coef_
# Out:
# array([1057.72211665])

# %%
lineus.intercept_
# Out:
# np.float64(-2083616.1349067031)

# %%
1057.72211665 * 2025 + -2083616.1349067031
# Out:
# 58271.151309547015

# %%
lineus.predict([[2025]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([58271.15131604])

# %%
plt.scatter(dfus['year'], dfus['income'], color='blue', marker= '+')
plt.plot(dfus['year'], lineus.predict(dfus[['year']]), color='red')
plt.xlabel('Year')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
lineus.predict([[2024]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57213.42919939])
